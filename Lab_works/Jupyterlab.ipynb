# %% [markdown]
# # <span style="color: green;">Big in Japan</span>

# %% [markdown]
# *In this notebook I will shortly exolain why one of my favorite places to visit is Japan.*

# %%
input("Who likes to visit Japan? (Pls enter name.)")
# Out:
# Who likes to visit Japn? (Pls enter name.)Inga
# 'Inga'

# %% [markdown]
# **Here is a picture of Inga and Stefan wearing classical Yukata**

# %%
from IPython import display
display.Image("C:/Users/ingae/Documents/Ironhack_DataAnalytics/IE_Japan.png")

# %%
input("Which city did you like best in Japan and why?")
# Out:
# Which city did you like best in Japan and why?Kyoto, because it was beautiful, but not as large as Tokyo. Also it has lost of temples and shreins which are super various and impressive.
# 'Kyoto, because it was beautiful, but not as large as Tokyo. Also it has lost of temples and shreins which are super various and impressive.'

# %% [markdown]
# **Here is a picture of Kyoto.**

# %%
from IPython import display
display.Image("https://www.chamaeleon-reisen.de/data/pic/img20/Reisen/Asien/JPKYO/Japan-Kyoto-001-Altstadt_1920x600.jpg")

# %% [markdown]
# **The top three things I like about Kyoto are:**
# 1. the temples and their quite, relaxing gardens
# 2. the nightlife, with lots of bars at the river
# 3. girls and women in colorful Kimonos walking around the whole old town

# %% [markdown]
# **Here is a short video of Kyoto**

# %%
from IPython.display import HTML

# Youtube
HTML('<iframe width="1237" height="696" src="https://www.youtube.com/embed/AnP_vePDLWY" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>')
# Out:
# C:\Users\ingae\anaconda3\lib\site-packages\IPython\core\display.py:717: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe width="1237" height="696" src="https://www.youtube.com/embed/AnP_vePDLWY" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
